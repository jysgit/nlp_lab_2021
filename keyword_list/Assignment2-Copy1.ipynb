# %% [markdown]
# # Assignment02: Find Academic Keyword List
# Academic Keywords are the words we seldom use ordinarily, but often use in Academic articles. "This shows" and "in conclusion" are examples of Academic Keywords. This assignment want you to use Rank Ratio and compare two dataset to find Academic Keyword List(AKL).
# <br><br>
# One dataset is taken from [`British Academic Written English Corpus(BAWE)`](https://www.coventry.ac.uk/research/research-directories/current-projects/2015/british-academic-written-english-corpus-bawe/), which collect a record of proficient university-level student writing. Hence, BAWE can be seen as Academic data. Another one is called [`Web1T`](https://catalog.ldc.upenn.edu/LDC2006T13), which is presented by Google. Web1T colloct 1 trillion words of English Web, so we can treat it as the representative of common words.

# %% [markdown]
# ## N-gram counting
# This part is almost same as what you need to do in Assignment01. The way to find N-gram is the same as Assignment01. However, tokenization and calculating frequency are a little different. The rules of tokenization in this Assignment are:
#  1. Ignore case (e.g., "The" is the same as "the")
#  2. Split by white spaces <s>and punctuations</s>
#  3. Ignore all punctuation
# <br><br>
#
# As for calculating frequency, we want you calculating <u>document frequency</u> in this Assignment. <br>What is document frequency?
# <br>Article 1:
# > We all know that water masses in the ocean are thought to be transferred by the wind. ...
#
# Althought there are at least 2 "the" in Article 1, the document frequency of "the" is still 1 in this article.<br> No mater how many times does "the" show up in Article 1, the document frquency of it is always 1.<br>
# Article 2:
# > The film Dantes Peak is about a dormant volcano that suddenly erupts and threatens the nearby town. ...
#
# Considering the Article 1 and 2, the document frequency of "the" is 2 now.<br>
# Document frequency can reduce the influence of terms, like "NLP".
# <br><br>
# <span style="color: red">[ TODO ]</span> Try to modify the functions coded in Assignment01 to <u>calculate document frequencies of all unigram.</u>.
#
# Google has calculated the frequency of N-gram, so you only need to do it on BAWE.

# %%
import os
import re
import string

# %%
def tokenize(text):
    # [ TODO ] transform to lower case
    text = ...
    # [ TODO ] seperate the words
    tokens = [text]
    return tokens

# %%
def tokenize(text):
    # [ TODO ] transform to lower case
    text = text.lower()
    text = re.sub(r'\n',' ',text)
    text = re.split("[" + string.punctuation +' ' + "]+", text)
    
    tokens = [ t for t in text if t ]
    
    return tokens

# %%
def calculate_frequency(tokens):
    # [ TODO ]
    frequency = {...} 
    """
    Sample output: 
    {
        'the': 79809, 
        'project': 288,
        ...
    }
    """
    return frequency

# %%
def calculate_frequency(tokens):
    # [ TODO ]
    import collections

    frequency=collections.Counter(tokens)
    #counter = counter.most_common()
    #frequency = {...} 
    """
    Sample output: 
    {
        'the': 79809, 
        'project': 288,
        ...
    }
    """
    return frequency

# %%
def get_ngram(tokens, n=2):
    ... # [ TODO ]
    return tokens

# %%
def get_ngram(tokens, n=2):
    ngram = []
    for i in range(len(tokens)):
        ngram.append(' '.join(tokens[i: i+n]))
    return ngram

# %%
# 找不到big.txt, 確認他是否在當前資料夾中
os.listdir()
# Out:
# ['Assignment2.ipynb',
#  '.ipynb_checkpoints',
#  'Web1T_unigram.txt',
#  'Web1T_bigram.txt',
#  'BAWE.txt',
#  'Assignment2-Copy1.ipynb']

# %%
# 確認現在位置
os.getcwd()
# Out:
# '/home/nlplab/jy/courses/NlpTA/keyword_list'

# %%
file_path = 'BAWE.txt'
BAWE_unigram = []
#### [ TODO ] calculate document frequency of unigram in BAWE
with open(file_path, 'r') as f:
    for text in f.readlines():
        BAWE_unigram.extend(tokenize(text))

# %%
# BAWE_unigram

# %%
counter = calculate_frequency(BAWE_unigram)
counter.most_common(10)
# Out:
# [('the', 434737),
#  ('of', 231931),
#  ('to', 172139),
#  ('and', 171900),
#  ('in', 131395),
#  ('a', 121035),
#  ('is', 100118),
#  ('that', 71961),
#  ('as', 61207),
#  ('be', 53289)]

# %%
# Read Web1T Data
file_path = 'Web1T_unigram.txt'
Web1T_unigram_counter = {}
with open(file_path,'r') as f:
    for line in f.readlines():
        line=line.rstrip("\n").split("\t")
        Web1T_unigram_counter[line[0]] = int(line[1])

# %% [markdown]
# ## Rank
# Rank unigrms by their frequencies. The higher the frequency, the higher the rank.(The most frequent unigram ranks 1.)<br>
# <span style="color: red">[ TODO ]</span> <u>Rank unigrams for Web1T and BAWE.</u>.

# %%
from collections import Counter

Web1T_unigram_Rank = {}
#### [ TODO ] Rank unigrams for Web1T
Web1T_unigram_counter = Counter(Web1T_unigram_counter)

# %%
c = 1
for k, v in Web1T_unigram_counter.most_common():
    Web1T_unigram_Rank[k] = c
    c += 1

# %%
BAWE_unigram_Rank = {}
#### [ TODO ] Rank unigrams for BAWE
c = 1
for k, v in counter.most_common():
    BAWE_unigram_Rank[k] = c
    c += 1

# %% [markdown]
# ## Calculate Rank Ratio
# In this step, you need to map the same unigram in two dataset, and caalculate the Rank Ratio of unigram in BAWE.  <br>Please follow the formula for calculating Rank Ratio:<br>
# <br>
# <img src="https://imgur.com/vmK7Q1K.jpg" width=30%><br>
# If the unigram doesn't appear in Web1T, the rank of it is treated as 1.
#
# <span style="color: red">[ TODO ]</span> Please calculate all rank ratios of unigrams in BAWE.

# %%
#### [TODO] calculate all rank ratios of unigrams in BAWE
res = []
for k in BAWE_unigram_Rank:
    try: 
        ratio = Web1T_unigram_Rank[k] / BAWE_unigram_Rank[k]
        res.append((k, ratio))
    except KeyError:
        ratio = 1 / BAWE_unigram_Rank[k]
        res.append((k, ratio))

# %%
res
# Out:
# [('the', 1.0),
#  ('of', 1.0),
#  ('to', 1.3333333333333333),
#  ('and', 0.75),
#  ('in', 1.2),
#  ('a', 0.8333333333333334),
#  ('is', 1.1428571428571428),
#  ('that', 1.25),
#  ('as', 2.5555555555555554),
#  ('be', 1.9),
#  ('for', 0.6363636363636364),
#  ('this', 1.0),
#  ('it', 1.2307692307692308),
#  ('are', 1.4285714285714286),
#  ('with', 0.8666666666666667),
#  ('by', 0.6875),
#  ('on', 0.5294117647058824),
#  ('was', 1.6666666666666667),
#  ('not', 0.8947368421052632),
#  ('s', 4.5),
#  ('from', 1.0),
#  ('which', 2.590909090909091),
#  ('an', 1.2608695652173914),
#  ('have', 1.0833333333333333),
#  ('can', 1.36),
#  ('or', 0.6923076923076923),
#  ('at', 0.8148148148148148),
#  ('has', 1.4285714285714286),
#  ('their', 2.0),
#  ('they', 1.7),
#  ('will', 1.032258064516129),
#  ('more', 0.875),
#  ('were', 2.6666666666666665),
#  ('also', 2.176470588235294),
#  ('there', 1.8),
#  ('but', 1.1944444444444444),
#  ('1', 0.02702702702702703),
#  ('would', 2.263157894736842),
#  ('one', 1.1538461538461537),
#  ('these', 2.325),
#  ('i', 0.34146341463414637),
#  ('we', 0.7380952380952381),
#  ('been', 1.9767441860465116),
#  ('2', 0.022727272727272728),
#  ('however', 10.355555555555556),
#  ('all', 0.5434782608695652),
#  ('such', 3.0638297872340425),
#  ('other', 0.9583333333333334),
#  ('his', 1.3673469387755102),
#  ('its', 1.9),
#  ('if', 0.7254901960784313),
#  ('when', 1.3076923076923077),
#  ('between', 4.90566037735849),
#  ('may', 1.0185185185185186),
#  ('than', 1.8),
#  ('he', 0.9464285714285714),
#  ('only', 1.1403508771929824),
#  ('so', 1.1379310344827587),
#  ('time', 0.847457627118644),
#  ('no', 0.8),
#  ('used', 2.0),
#  ('could', 3.3548387096774195),
#  ('into', 1.8095238095238095),
#  ('had', 1.65625),
#  ('3', 0.015384615384615385),
#  ('two', 1.7575757575757576),
#  ('some', 1.373134328358209),
#  ('different', 6.1911764705882355),
#  ('therefore', 18.884057971014492),
#  ('p', 2.942857142857143),
#  ('use', 0.8591549295774648),
#  ('should', 1.8611111111111112),
#  ('new', 0.3698630136986301),
#  ('what', 0.7567567567567568),
#  ('then', 2.04),
#  ('being', 3.6447368421052633),
#  ('most', 1.6493506493506493),
#  ('many', 2.358974358974359),
#  ('both', 3.7974683544303796),
#  ('who', 0.9),
#  ('them', 1.6419753086419753),
#  ('people', 1.2804878048780488),
#  ('system', 1.6385542168674698),
#  ('social', 6.642857142857143),
#  ('because', 2.776470588235294),
#  ('through', 1.930232558139535),
#  ('how', 1.0),
#  ('out', 0.6818181818181818),
#  ('her', 1.550561797752809),
#  ('each', 1.8666666666666667),
#  ('where', 1.7472527472527473),
#  ('about', 0.391304347826087),
#  ('order', 1.8602150537634408),
#  ('first', 0.8829787234042553),
#  ('any', 0.6526315789473685),
#  ('within', 2.6145833333333335),
#  ('4', 0.010309278350515464),
#  ('very', 1.7755102040816326),
#  ('over', 1.1111111111111112),
#  ('up', 0.54),
#  ('way', 2.00990099009901),
#  ('5', 0.00980392156862745),
#  ('important', 5.563106796116505),
#  ('figure', 9.211538461538462),
#  ('using', 2.276190476190476),
#  ('world', 1.1226415094339623),
#  ('example', 5.4485981308411215),
#  ('due', 7.046296296296297),
#  ('women', 2.55045871559633),
#  ('do', 0.42727272727272725),
#  ('well', 1.4144144144144144),
#  ('work', 1.1160714285714286),
#  ('high', 1.4513274336283186),
#  ('data', 1.1491228070175439),
#  ('same', 2.5130434782608697),
#  ('state', 0.9568965517241379),
#  ('does', 1.606837606837607),
#  ('market', 3.983050847457627),
#  ('e', 0.6890756302521008),
#  ('power', 2.558333333333333),
#  ('must', 1.8016528925619835),
#  ('results', 1.9672131147540983),
#  ('0', 0.008130081300813009),
#  ('even', 2.1774193548387095),
#  ('number', 1.144),
#  ('after', 1.1904761904761905),
#  ('process', 3.393700787401575),
#  ('found', 2.3046875),
#  ('she', 1.317829457364341),
#  ('although', 7.823076923076923),
#  ('made', 1.6946564885496183),
#  ('theory', 12.492424242424242),
#  ('case', 2.1578947368421053),
#  ('those', 1.7761194029850746),
#  ('model', 3.525925925925926),
#  ('thus', 10.095588235294118),
#  ('value', 2.9927007299270074),
#  ('see', 0.463768115942029),
#  ('development', 1.60431654676259),
#  ('much', 1.9928571428571429),
#  ('our', 0.3120567375886525),
#  ('level', 2.563380281690141),
#  ('analysis', 4.3776223776223775),
#  ('since', 2.361111111111111),
#  ('research', 1.3241379310344827),
#  ('group', 1.2397260273972603),
#  ('during', 2.4149659863945576),
#  ('information', 0.3310810810810811),
#  ('form', 2.469798657718121),
#  ('al', 4.133333333333334),
#  ('control', 2.205298013245033),
#  ('seen', 6.7894736842105265),
#  ('part', 1.3529411764705883),
#  ('make', 0.8571428571428571),
#  ('et', 4.916129032258064),
#  ('possible', 4.0576923076923075),
#  ('need', 1.1656050955414012),
#  ('law', 2.1012658227848102),
#  ('economic', 5.415094339622642),
#  ('society', 4.44375),
#  ('human', 2.987577639751553),
#  ('political', 6.074074074074074),
#  ('life', 1.2269938650306749),
#  ('another', 2.341463414634146),
#  ('based', 1.606060606060606),
#  ('like', 0.5783132530120482),
#  ('change', 2.0778443113772456),
#  ('us', 0.20833333333333334),
#  ('t', 0.8284023668639053),
#  ('increase', 5.794117647058823),
#  ('further', 4.233918128654971),
#  ('language', 3.2674418604651163),
#  ('fact', 4.936416184971098),
#  ('three', 1.8045977011494252),
#  ('6', 0.005714285714285714),
#  ('result', 3.471590909090909),
#  ('point', 2.4745762711864407),
#  ('good', 0.8707865168539326),
#  ('often', 4.837988826815643),
#  ('given', 3.4555555555555557),
#  ('still', 2.154696132596685),
#  ('study', 2.791208791208791),
#  ('my', 0.21311475409836064),
#  ('less', 2.907608695652174),
#  ('rate', 1.9027027027027028),
#  ('before', 1.2365591397849462),
#  ('while', 1.6470588235294117),
#  ('own', 1.5638297872340425),
#  ('evidence', 6.91005291005291),
#  ('c', 0.4263157894736842),
#  ('2004', 0.005235602094240838),
#  ('states', 1.3125),
#  ('business', 0.36787564766839376),
#  ('2003', 0.005154639175257732),
#  ('years', 0.882051282051282),
#  ('company', 0.9081632653061225),
#  ('under', 0.9644670050761421),
#  ('set', 0.9545454545454546),
#  ('long', 1.3266331658291457),
#  ('method', 4.755),
#  ('whether', 3.781094527363184),
#  ('able', 3.599009900990099),
#  ('management', 1.0098522167487685),
#  ('non', 1.8627450980392157),
#  ('means', 3.678048780487805),
#  ('individual', 4.087378640776699),
#  ('international', 1.038647342995169),
#  ('large', 2.2211538461538463),
#  ('nature', 4.794258373205742),
#  ('values', 5.457142857142857),
#  ('product', 0.6398104265402843),
#  ('effect', 5.05188679245283),
#  ('rather', 5.136150234741784),
#  ('role', 5.107476635514018),
#  ('main', 1.7348837209302326),
#  ('project', 1.3333333333333333),
#  ('problem', 2.5483870967741935),
#  ('did', 1.0642201834862386),
#  ('2005', 0.0045662100456621),
#  ('history', 1.5227272727272727),
#  ('table', 2.0995475113122173),
#  ('countries', 4.373873873873874),
#  ('higher', 4.376681614349776),
#  ('without', 1.4375),
#  ('take', 1.0933333333333333),
#  ('food', 1.8495575221238938),
#  ('2001', 0.004405286343612335),
#  ('against', 2.3201754385964914),
#  ('shows', 4.135371179039302),
#  ('you', 0.06521739130434782),
#  ('structure', 5.190476190476191),
#  ('government', 1.521551724137931),
#  ('above', 2.347639484978541),
#  ('shown', 4.9914529914529915),
#  ('just', 0.46382978723404256),
#  ('following', 1.347457627118644),
#  ('low', 1.6962025316455696),
#  ('now', 0.31512605042016806),
#  ('factors', 8.121338912133892),
#  ('present', 3.3541666666666665),
#  ('10', 0.004149377593360996),
#  ('production', 3.652892561983471),
#  ('2002', 0.00411522633744856),
#  ('terms', 0.9385245901639344),
#  ('approach', 5.16734693877551),
#  ('2000', 0.0040650406504065045),
#  ('g', 1.2186234817813766),
#  ('health', 0.4717741935483871),
#  ('small', 1.4056224899598393),
#  ('right', 0.936),
#  ('water', 1.3306772908366533),
#  ('knowledge', 3.5595238095238093),
#  ('problems', 2.5573122529644268),
#  ('provide', 1.6377952755905512),
#  ('place', 1.2392156862745098),
#  ('cost', 1.91015625),
#  ('significant', 5.470817120622568),
#  ('7', 0.003875968992248062),
#  ('period', 2.9575289575289574),
#  ('general', 0.7346153846153847),
#  ('growth', 3.8659003831417627),
#  ('b', 0.4732824427480916),
#  ('war', 2.338403041825095),
#  ('class', 1.4696969696969697),
#  ('taken', 3.479245283018868),
#  ('m', 0.6278195488721805),
#  ('children', 1.3258426966292134),
#  ('policy', 0.5298507462686567),
#  ('certain', 4.089219330855019),
#  ('ibid', 48.455555555555556),
#  ('similar', 2.4391143911439115),
#  ('public', 0.5955882352941176),
#  ('area', 0.9267399267399268),
#  ('support', 0.5401459854014599),
#  ('trade', 2.610909090909091),
#  ('cannot', 386.213768115942),
#  ('performance', 2.0108303249097474),
#  ('r', 0.6438848920863309),
#  ('year', 0.4014336917562724),
#  ('increased', 5.946428571428571),
#  ('upon', 2.7224199288256226),
#  ('second', 1.7234042553191489),
#  ('according', 3.9151943462897525),
#  ('making', 2.2183098591549295),
#  ('test', 1.7614035087719297),
#  ('likely', 5.178321678321678),
#  ('self', 2.4285714285714284),
#  ('end', 1.1006944444444444),
#  ('become', 2.2560553633217992),
#  ('products', 0.4413793103448276),
#  ('quality', 1.3470790378006874),
#  ('particular', 3.8116438356164384),
#  ('8', 0.0034129692832764505),
#  ('1999', 0.003401360544217687),
#  ('view', 0.2677966101694915),
#  ('culture', 3.9594594594594597),
#  ('term', 2.276094276094276),
#  ('relationship', 5.75503355704698),
#  ('environment', 2.62876254180602),
#  ('energy', 2.236666666666667),
#  ('changes', 1.9700996677740863),
#  ('common', 2.437086092715232),
#  ('groups', 2.042904290429043),
#  ('design', 0.805921052631579),
#  ('men', 1.4459016393442623),
#  ('needs', 2.065359477124183),
#  ('section', 0.9543973941368078),
#  ('him', 1.0422077922077921),
#  ('current', 1.0614886731391586),
#  ('seems', 4.809677419354839),
#  ('idea', 3.967845659163987),
#  ('considered', 4.589743589743589),
#  ('around', 1.3610223642172523),
#  ('future', 2.0414012738853504),
#  ('show', 0.8507936507936508),
#  ('function', 2.699367088607595),
#  ('required', 1.5299684542586751),
#  ('experience', 1.779874213836478),
#  ('behaviour', 14.918495297805643),
#  ('v', 1.121875),
#  ('uk', 0.9065420560747663),
#  ('might', 1.968944099378882),
#  ('better', 1.5325077399380804),
#  ('line', 0.7037037037037037),
#  ('areas', 1.9692307692307693),
#  ('question', 1.8159509202453987),
#  ('greater', 4.525993883792049),
#  ('act', 1.6829268292682926),
#  ('great', 0.6352583586626139),
#  ('d', 0.47878787878787876),
#  ('price', 0.30513595166163143),
#  ('levels', 3.5903614457831323),
#  ('having', 2.186186186186186),
#  ('amount', 2.604790419161677),
#  ('labour', 10.525373134328358),
#  ('best', 0.4494047619047619),
#  ('european', 3.0089020771513355),
#  ('specific', 2.1834319526627217),
#  ('local', 0.6991150442477876),
#  ('population', 3.8147058823529414),
#  ('age', 1.7008797653958945),
#  ('introduction', 3.912280701754386),
#  ('towards', 6.396501457725948),
#  ('lower', 3.2093023255813953),
#  ('cause', 3.544927536231884),
#  ('sample', 3.367052023121387),
#  ('methods', 2.6253602305475505),
#  ('species', 5.344827586206897),
#  ('help', 0.2177650429799427),
#  ('too', 1.2457142857142858),
#  ('hence', 13.01139601139601),
#  ('potential', 3.477272727272727),
#  ('body', 1.614730878186969),
#  ('clear', 2.562146892655367),
#  ('x', 0.27605633802816903),
#  ('position', 2.587078651685393),
#  ('systems', 0.876750700280112),
#  ('though', 2.441340782122905),
#  ('per', 0.8997214484679665),
#  ('sense', 4.355555555555555),
#  ('find', 0.2770083102493075),
#  ('working', 1.4585635359116023),
#  ('yet', 1.7520661157024793),
#  ('early', 2.2005494505494507),
#  ('effects', 2.6767123287671235),
#  ('range', 1.6530054644808743),
#  ('l', 0.7166212534059946),
#  ('pressure', 4.369565217391305),
#  ('customers', 2.5826558265582658),
#  ('why', 1.0405405405405406),
#  ('type', 0.633423180592992),
#  ('report', 0.6021505376344086),
#  ('interest', 1.7506702412868633),
#  ('key', 1.5213903743315509),
#  ('conditions', 1.2053333333333334),
#  ('man', 1.0984042553191489),
#  ('national', 0.6445623342175066),
#  ('various', 2.328042328042328),
#  ('give', 1.4643799472295516),
#  ('modern', 3.8),
#  ('industry', 1.2572178477690288),
#  ('issues', 1.356020942408377),
#  ('material', 2.1201044386422976),
#  ('words', 2.2942708333333335),
#  ('known', 2.4077922077922076),
#  ('hand', 1.6683937823834196),
#  ('9', 0.002583979328165375),
#  ('here', 0.18041237113402062),
#  ('1998', 0.002570694087403599),
#  ('strategy', 3.68974358974359),
#  ('rights', 0.4117647058823529),
#  ('person', 1.3571428571428572),
#  ('others', 1.7964376590330788),
#  ('down', 0.7893401015228426),
#  ('itself', 4.113924050632911),
#  ('necessary', 2.79040404040404),
#  ('economy', 4.4811083123425695),
#  ('country', 0.9949748743718593),
#  ('decision', 2.827067669172932),
#  ('understanding', 4.175),
#  ('difficult', 4.807980049875312),
#  ('available', 0.36318407960199006),
#  ('conclusion', 10.017369727047146),
#  ('learning', 1.6584158415841583),
#  ('force', 2.523456790123457),
#  ('suggests', 11.37192118226601),
#  ('light', 1.5061425061425062),
#  ('reason', 3.053921568627451),
#  ('natural', 1.8557457212713937),
#  ('far', 2.097560975609756),
#  ('risk', 2.1313868613138687),
#  ('either', 1.9587378640776698),
#  ('demand', 4.428571428571429),
#  ('free', 0.10144927536231885),
#  ('again', 1.2409638554216869),
#  ('essay', 13.197115384615385),
#  ('output', 3.5419664268585134),
#  ('service', 0.23205741626794257),
#  ('total', 0.7517899761336515),
#  ('financial', 1.2523809523809524),
#  ('account', 0.8574821852731591),
#  ('flow', 4.187203791469194),
#  ('positive', 3.4680851063829787),
#  ('little', 0.9386792452830188),
#  ('every', 0.9247058823529412),
#  ('stage', 3.6901408450704225),
#  ('impact', 3.128805620608899),
#  ('cultural', 4.549065420560748),
#  ('concept', 5.853146853146853),
#  ('major', 1.4837209302325582),
#  ('left', 1.0394431554524362),
#  ('english', 1.0347222222222223),
#  ('difference', 4.2609699769053115),
#  ('influence', 6.78110599078341),
#  ('factor', 4.804597701149425),
#  ('source', 0.9610091743119266),
#  ('times', 0.8283752860411899),
#  ('temperature', 4.3744292237442925),
#  ('four', 1.366742596810934),
#  ('whilst', 14.518181818181818),
#  ('community', 0.5668934240362812),
#  ('always', 1.3800904977375565),
#  ('appendix', 7.367945823927765),
#  ('once', 1.587837837837838),
#  ('increasing', 6.269662921348314),
#  ('importance', 6.605381165919282),
#  ('size', 0.7539149888143176),
#  ('developed', 2.8660714285714284),
#  ('ability', 3.538975501113586),
#  ('real', 0.4711111111111111),
#  ('especially', 3.057649667405765),
#  ('below', 1.1792035398230087),
#  ('situation', 4.198675496688741),
#  ('1997', 0.0022026431718061676),
#  ('including', 0.7494505494505495),
#  ('family', 0.5745614035087719),
#  ('meaning', 6.048140043763676),
#  ('child', 1.4301310043668123),
#  ('solution', 2.3769063180827885),
#  ('themselves', 3.7934782608695654),
#  ('compared', 5.047722342733189),
#  ('associated', 2.686147186147186),
#  ('costs', 1.7084233261339092),
#  ('individuals', 3.8922413793103448),
#  ('negative', 5.602150537634409),
#  ('action', 1.0150214592274678),
#  ('lack', 5.349036402569594),
#  ('experiment', 9.876068376068377),
#  ('produced', 4.40724946695096),
#  ('past', 1.6127659574468085),
#  ('american', 0.643312101910828),
#  ('strong', 2.8389830508474576),
#  ('lead', 2.4862579281183934),
#  ('involved', 2.9029535864978904),
#  ('j', 0.8778947368421053),
#  ('studies', 1.5420168067226891),
#  ('physical', 2.660377358490566),
#  ('care', 0.6464435146443515),
#  ('site', 0.10855949895615867),
#  ('produce', 4.735416666666667),
#  ('ideas', 2.4885654885654884),
#  ('perhaps', 3.995850622406639),
#  ('whole', 1.94824016563147),
#  ('focus', 2.541322314049587),
#  ('several', 1.5237113402061855),
#  ('graph', 9.162551440329219),
#  ('include', 0.837782340862423),
#  ('despite', 5.764344262295082),
#  ('addition', 2.2413087934560325),
#  ('back', 0.21020408163265306),
#  ('n', 0.24032586558044808),
#  ('particularly', 3.9430894308943087),
#  ('standard', 1.075050709939148),
#  ('thought', 2.006072874493927),
#  ('global', 1.7313131313131314),
#  ('cases', 1.872983870967742),
#  ('provided', 0.9698189134808853),
#  ('practice', 1.9196787148594376),
#  ('argument', 4.162324649298597),
#  ('land', 1.546),
#  ('single', 1.1536926147704591),
#  ('issue', 1.203187250996016),
#  ('capital', 2.3121272365805168),
#  ('mean', 2.0),
#  ('few', 1.1386138613861385),
#  ('employees', 2.930830039525692),
#  ('forms', 2.5207100591715976),
#  ('throughout', 3.188976377952756),
#  ('true', 1.6326129666011788),
#  ('get', 0.15098039215686274),
#  ('customer', 0.7906066536203522),
#  ('extent', 6.03515625),
#  ('differences', 6.003898635477583),
#  ('resources', 0.6361867704280155),
#  ('points', 1.7398058252427184),
#  ('activity', 1.9670542635658914),
#  ('short', 1.4429400386847195),
#  ('expected', 2.9266409266409266),
#  ('error', 1.7321772639691715),
#  ('clearly', 4.736538461538461),
#  ('members', 0.5873320537428023),
#  ('treatment', 1.710727969348659),
#  ('direct', 1.497131931166348),
#  ('makes', 1.7423664122137406),
#  ('indeed', 5.514285714285714),
#  ('done', 1.473384030418251),
#  ('day', 0.2144212523719165),
#  ('last', 0.23863636363636365),
#  ('until', 1.3119092627599245),
#  ('know', 0.37924528301886795),
#  ('needed', 1.9943502824858756),
#  ('related', 0.5601503759398496),
#  ('create', 1.0656660412757974),
#  ('1995', 0.0018726591760299626),
#  ('h', 0.5981308411214953),
#  ('later', 1.7611940298507462),
#  ('complex', 3.2737430167597767),
#  ('environmental', 1.8401486988847584),
#  ('communication', 2.3320964749536177),
#  ('disease', 2.501851851851852),
#  ('legal', 1.009242144177449),
#  ('simply', 2.407749077490775),
#  ('subject', 0.47697974217311234),
#  ('context', 3.6801470588235294),
#  ('understand', 2.4073394495412845),
#  ('led', 3.1923076923076925),
#  ('enough', 1.7605118829981719),
#  ('field', 1.0474452554744527),
#  ('called', 1.3570127504553735),
#  ('death', 1.7581818181818183),
#  ('off', 0.40834845735027225),
#  ('1996', 0.0018115942028985507),
#  ('gender', 4.93128390596745),
#  ('ways', 2.5541516245487363),
#  ('technology', 0.5135135135135135),
#  ('services', 0.16366906474820145),
#  ('consider', 2.74326750448833),
#  ('loss', 1.7419354838709677),
#  ('already', 1.3094812164579606),
#  ('feel', 1.5589285714285714),
#  ('processes', 3.655971479500891),
#  ('surface', 2.9412811387900355),
#  ('image', 0.6678507992895204),
#  ('movement', 4.065602836879433),
#  ('organisation', 5.971681415929203),
#  ('together', 1.5),
#  ('effective', 1.8835978835978835),
#  ('instead', 2.561619718309859),
#  ('central', 1.2056239015817223),
#  ('companies', 1.1701754385964913),
#  ('equation', 8.926444833625219),
#  ('f', 0.3723776223776224),
#  ('put', 1.1849912739965096),
#  ('limited', 1.3083623693379791),
#  ('successful', 3.2991304347826085),
#  ('average', 1.34375),
#  ('success', 2.4020797227036397),
#  ('female', 2.13840830449827),
#  ('look', 0.770293609671848),
#  ('personal', 0.5844827586206897),
#  ('response', 1.6437177280550774),
#  ('applied', 3.134020618556701),
#  ('appears', 4.135506003430532),
#  ('furthermore', 9.544520547945206),
#  ('types', 1.7965811965811966),
#  ('useful', 2.409556313993174),
#  ('team', 0.7649063032367973),
#  ('staff', 0.8690476190476191),
#  ('money', 0.6638370118845501),
#  ('british', 1.9152542372881356),
#  ('male', 2.047377326565144),
#  ('caused', 4.8800675675675675),
#  ('century', 2.5379426644182126),
#  ('cited', 9.533670033670033),
#  ('among', 1.6235294117647059),
#  ('relations', 2.5067114093959733),
#  ('created', 1.6381909547738693),
#  ('me', 0.1488294314381271),
#  ('simple', 1.5575959933222037),
#  ('reasons', 3.6733333333333333),
#  ('affect', 5.224625623960066),
#  ('reduce', 3.382059800664452),
#  ('profit', 3.8374792703150913),
#  ('europe', 1.3874172185430464),
#  ('mass', 3.3206611570247935),
#  ('appropriate', 1.900990099009901),
#  ('12', 0.0016474464579901153),
#  ('program', 0.32730263157894735),
#  ('20', 0.0016420361247947454),
#  ('cells', 3.0524590163934424),
#  ('final', 1.3420621931260228),
#  ('education', 0.3954248366013072),
#  ('cell', 1.133768352365416),
#  ('ensure', 2.234527687296417),
#  ('marketing', 1.1739837398373985),
#  ('generally', 3.2564935064935066),
#  ('status', 0.9756888168557536),
#  ('seem', 3.5436893203883497),
#  ('critical', 2.880452342487884),
#  ('defined', 2.6225806451612903),
#  ('provides', 1.173913043478261),
#  ('least', 1.1414790996784565),
#  ('constant', 5.337078651685394),
#  ('traditional', 2.7580128205128207),
#  ('home', 0.0528),
#  ('questions', 0.7939297124600639),
#  ('never', 0.8293460925039873),
#  ('moral', 7.808917197452229),
#  ('11', 0.001589825119236884),
#  ('something', 0.9349206349206349),
#  ('suggest', 3.484944532488114),
#  ('argued', 12.705696202531646),
#  ('activities', 0.9178515007898894),
#  ('play', 0.8138801261829653),
#  ('next', 0.19055118110236222),
#  ('previous', 0.5770440251572327),
#  ('mind', 1.6860282574568288),
#  ('students', 0.5611285266457681),
#  ('patient', 3.003129890453834),
#  ('believe', 1.6703125),
#  ('reduced', 4.180967238689548),
#  ('poor', 2.6651090342679127),
#  ('open', 0.4401244167962675),
#  ('carried', 4.46583850931677),
#  ('god', 1.069767441860465),
#  ('book', 0.2724458204334365),
#  ('highly', 2.945904173106646),
#  ('2006', 0.0015432098765432098),
#  ('foreign', 1.8305084745762712),
#  ('gives', 2.76),
#  ('said', 0.2857142857142857),
#  ('taking', 1.7561349693251533),
#  ('scale', 2.7212863705972437),
#  ('finally', 2.5642201834862384),
#  ('benefits', 1.615267175572519),
#  ('distribution', 1.858231707317073),
#  ('ratio', 4.480974124809741),
#  ('longer', 2.3206686930091185),
#  ('word', 1.2291350531107739),
#  ('1994', 0.0015151515151515152),
#  ('features', 0.7216338880484114),
#  ('allow', 1.8157099697885197),
#  ('your', 0.03619909502262444),
#  ('protein', 2.3313253012048194),
#  ('discussion', 1.0571428571428572),
#  ('usually', 1.2717717717717718),
#  ('review', 0.2563718140929535),
#  ('occur', 4.655688622754491),
#  ('share', 0.9865470852017937),
#  ('pp', 2.7313432835820897),
#  ('aspects', 4.1698956780923995),
#  ('come', 0.75),
#  ('k', 0.5661218424962853),
#  ('across', 1.5682492581602374),
#  ('fig', 5.614814814814815),
#  ('say', 0.7337278106508875),
#  ('characteristics', 4.6779911373707534),
#  ('reaction', 5.84070796460177),
#  ('phase', 2.9351988217967597),
#  ('described', 2.6882352941176473),
#  ('quite', 2.0425844346549193),
#  ('turn', 1.4765395894428153),
#  ('sales', 0.6515373352855052),
#  ('became', 3.162280701754386),
#  ('identified', 3.5036496350364965),
#  ('relatively', 5.432944606413995),
#  ('actually', 1.6826783114992723),
#  ('overall', 1.489825581395349),
#  ('air', 0.6937590711175616),
#  ('science', 0.6376811594202898),
#  ('black', 0.3921852387843705),
#  ('theories', 9.765895953757225),
#  ('workers', 2.4761904761904763),
#  ('access', 0.4668587896253602),
#  ('city', 0.2),
#  ('skills', 1.6091954022988506),
#  ('content', 0.5667144906743186),
#  ('discussed', 4.391117478510028),
#  ('side', 0.7882689556509299),
#  ('variables', 4.557142857142857),
#  ('income', 1.456490727532097),
#  ('suggested', 4.299145299145299),
#  ('gain', 3.543385490753912),
#  ('initial', 2.7982954545454546),
#  ('third', 1.1843971631205674),
#  ('basis', 1.9277620396600565),
#  ('competition', 2.939179632248939),
#  ('policies', 1.2923728813559323),
#  ('text', 0.4922425952045134),
#  ('relation', 4.776056338028169),
#  ('materials', 1.348804500703235),
#  ('recent', 0.7696629213483146),
#  ('page', 0.05329593267882188),
#  ('full', 0.27450980392156865),
#  ('justice', 2.5426573426573427),
#  ('established', 2.2835195530726256),
#  ('15', 0.001394700139470014),
#  ('go', 0.1713091922005571),
#  ('almost', 1.6884561891515995),
#  ('exchange', 1.4583333333333333),
#  ('looking', 0.7170596393897365),
#  ('article', 0.5692520775623269),
#  ('along', 1.334716459197787),
#  ('developing', 2.638121546961326),
#  ('basic', 1.303448275862069),
#  ('th', 2.422865013774105),
#  ('run', 0.9243466299862448),
#  ('uses', 2.0274725274725274),
#  ('determine', 2.625514403292181),
#  ('becomes', 3.915068493150685),
#  ('aim', 3.7633378932968538),
#  ('directly', 1.930327868852459),
#  ('university', 0.26330150068212826),
#  ('speech', 3.483651226158038),
#  ('explain', 4.193197278911565),
#  ('patients', 1.8953804347826086),
#  ('politics', 2.1112618724559025),
#  ('argues', 14.008130081300813),
#  ('domestic', 3.0433017591339646),
#  ('input', 1.9432432432432432),
#  ('white', 0.46963562753036436),
#  ('rates', 0.7641509433962265),
#  ('rise', 3.6379542395693134),
#  ('investment', 1.5672043010752688),
#  ('china', 0.8442953020134228),
#  ('definition', 2.3941018766756033),
#  ('re', 0.1606425702811245),
#  ('task', 2.7205882352941178),
#  ('choice', 1.5727636849132176),
#  ('five', 1.0186666666666666),
#  ('rules', 1.0905459387483356),
#  ('000', 0.0013297872340425532),
#  ('paper', 0.7662682602921647),
#  ('appear', 2.5305039787798407),
#  ('develop', 1.9629139072847681),
#  ('achieve', 3.791005291005291),
#  ('co', 0.9022457067371202),
#  ('away', 0.9221635883905013),
#  ('increases', 4.55862977602108),
#  ('think', 0.4276315789473684),
#  ('improve', 1.742444152431012),
#  ('techniques', 2.641732283464567),
#  ('america', 0.7496723460026212),
#  ('conflict', 4.06544502617801),
#  ('farm', 2.2444444444444445),
#  ('allows', 2.0182767624020888),
#  ('obtained', 3.117340286831812),
#  ('degree', 1.56640625),
#  ('complete', 0.6788036410923277),
#  ('speed', 1.2584415584415585),
#  ('elements', 2.411154345006485),
#  ('revolution', 4.884715025906735),
#  ('eu', 2.9495472186287195),
#  ('o', 0.3475452196382429),
#  ('samples', 3.4658064516129032),
#  ('majority', 3.5966494845360826),
#  ('organic', 4.0797940797940795),
#  ('added', 0.8547557840616966),
#  ('supply', 1.4094993581514763),
#  ('moreover', 7.023076923076923),
#  ('things', 0.674775928297055),
#  ('calculated', 5.40920716112532),
#  ('heat', 2.5887611749680715),
#  ('security', 0.38137755102040816),
#  ('normal', 1.8573248407643312),
#  ('matter', 1.5407124681933841),
#  ('training', 0.5527318932655655),
#  ('condition', 1.3540609137055837),
#  ('internet', 0.31432192648922685),
#  ('remains', 3.8240506329113924),
#  ('prices', 0.3463969658659924),
#  ('mentioned', 3.515151515151515),
#  ('private', 0.5006305170239597),
#  ('decisions', 3.2052896725440805),
#  ('1993', 0.0012578616352201257),
#  ('causes', 4.130653266331659),
#  ('presence', 3.4905897114178166),
#  ('today', 0.3558897243107769),
#  ('old', 0.4643304130162703),
#  ('tourism', 3.02875),
#  ('external', 2.049937578027466),
#  ('london', 0.8079800498753117),
#  ('1990', 0.0012453300124533001),
#  ('blood', 1.6455223880597014),
#  ('whereas', 5.772670807453416),
#  ('participants', 3.2245657568238215),
#  ('equal', 2.8612143742255265),
#  ('identity', 3.628712871287129),
#  ('essential', 2.634116192830655),
#  ('existence', 5.401234567901234),
#  ('larger', 1.6399506781750925),
#  ('post', 0.1687192118226601),
#  ('goods', 1.936039360393604),
#  ('comparison', 2.77027027027027),
#  ('failure', 2.795092024539877),
#  ('north', 0.39950980392156865),
#  ('stress', 3.6585067319461446),
#  ('exist', 3.7188264058679708),
#  ('y', 0.46642246642246643),
#  ('instance', 3.6158536585365852),
#  ('medical', 0.610231425091352),
#  ('attention', 2.2335766423357666),
#  ('relevant', 2.206561360874848),
#  ('achieved', 5.025485436893204),
#  ('space', 0.7781818181818182),
#  ('reader', 1.9757869249394673),
#  ('1992', 0.0012091898428053204),
#  ('code', 0.322463768115942),
#  ('purpose', 1.517490952955368),
#  ('events', 0.44457831325301206),
#  ('course', 0.5150421179302046),
#  ('target', 1.9038461538461537),
#  ('claim', 2.4273709483793517),
#  ('measure', 2.9772182254196644),
#  ('existing', 1.6646706586826348),
#  ('union', 1.3229665071770336),
#  ('application', 0.6081242532855436),
#  ('affected', 3.7625298329355608),
#  ('sector', 2.00834326579261),
#  ('software', 0.18095238095238095),
#  ('actual', 2.2829964328180736),
#  ('providing', 1.6840855106888362),
#  ('character', 1.8813760379596678),
#  ('young', 0.6765402843601895),
#  ('argue', 8.378698224852071),
#  ('building', 0.7163120567375887),
#  ('united', 0.24793388429752067),
#  ('observed', 3.831367924528302),
#  ('reality', 2.9623085983510014),
#  ('easily', 2.2929411764705883),
#  ('attempt', 3.591069330199765),
#  ('weight', 1.0410798122065728),
#  ('efficiency', 3.881594372801876),
#  ('hard', 0.6978922716627635),
#  ('reading', 0.9812865497076023),
#  ('consumers', 4.016355140186916),
#  ('identify', 2.618436406067678),
#  ('close', 0.8566433566433567),
#  ('frequency', 3.109429569266589),
#  ('maximum', 1.6127906976744186),
#  ('length', 1.3414634146341464),
#  ('takes', 1.6496519721577727),
#  ('living', 0.8597914252607184),
#  ('internal', 1.8206018518518519),
#  ('de', 0.2161849710982659),
#  ('region', 0.9006928406466512),
#  ('independent', 1.4579008073817763),
#  ('principle', 4.867511520737327),
#  ('east', 0.6628308400460299),
#  ('user', 0.21264367816091953),
#  ('included', 1.0011481056257177),
#  ('object', 1.3188073394495412),
#  ('literature', 2.0263459335624283),
#  ('examples', 2.4919908466819223),
#  ('lines', 1.2045714285714286),
#  ('face', 1.110730593607306),
#  ('allowed', 2.104903078677309),
#  ('markets', 2.1685649202733486),
#  ('milk', 4.0580204778157),
#  ('50', 0.0011363636363636363),
#  ('britain', 3.7525539160045405),
#  ('capacity', 1.91156462585034),
#  ('computer', 0.35334088335220837),
#  ('properties', 1.5203619909502262),
#  ('primary', 1.4045197740112993),
#  ('forces', 2.6478555304740405),
#  ('middle', 1.286358511837655),
#  ('actions', 2.1283783783783785),
#  ('benefit', 1.9426321709786276),
#  ('principles', 2.8752808988764045),
#  ('mainly', 4.808080808080808),
#  ('rule', 1.5908071748878925),
#  ('deal', 1.4266517357222845),
#  ('pre', 1.2662192393736018),
#  ('original', 0.7720670391061453),
#  ('models', 1.0323660714285714),
#  ('house', 0.3311036789297659),
#  ('linear', 3.6937639198218264),
#  ('centre', 0.9165739710789766),
#  ('sources', 1.4388888888888889),
#  ('consumer', 1.3152053274139845),
#  ('regarding', 1.8237250554323725),
#  ('advantage', 2.6788482834994465),
#  ('institutions', 2.563053097345133),
#  ('interaction', 4.141436464088398),
#  ('authority', 1.5794701986754967),
#  ('1991', 0.0011025358324145535),
#  ('probably', 1.4504405286343611),
#  ('accurate', 3.372937293729373),
#  ('series', 0.521978021978022),
#  ('outside', 1.3062568605927551),
#  ('structures', 3.3201754385964914),
#  ('job', 0.46987951807228917),
#  ('maintain', 2.649890590809628),
#  ('plant', 1.692896174863388),
#  ('determined', 2.541484716157205),
#  ('30', 0.0010905125408942203),
#  ('court', 0.6623093681917211),
#  ('strategies', 2.380848748639826),
#  ('placed', 2.472826086956522),
#  ('going', 0.5428881650380022),
#  ('move', 1.2386117136659436),
#  ('element', 2.4073672806067172),
#  ('held', 1.1504329004329004),
#  ('interests', 2.227027027027027),
#  ('note', 0.49676025917926564),
#  ('stated', 2.5965480043149944),
#  ('firstly', 16.523706896551722),
#  ('practical', 2.9440258342303554),
#  ('strength', 3.0258064516129033),
#  ('13', 0.0010741138560687433),
#  ('variable', 2.4881974248927037),
#  ('showed', 3.6634512325830655),
#  ('responsibility', 1.5920770877944326),
#  ('believed', 5.189304812834225),
#  ('contrast', 4.262820512820513),
#  ('interpretation', 4.615795090715048),
#  ('numbers', 1.3272921108742004),
#  ('distance', 1.4568690095846646),
#  ('party', 0.5723404255319149),
#  ('works', 0.8618490967056323),
#  ('firm', 1.9681528662420382),
#  ('pain', 2.0551431601272534),
#  ('himself', 2.1588983050847457),
#  ('relative', 3.0973544973544973),
#  ('resulting', 3.6501057082452433),
#  ('plan', 0.5068637803590285),
#  ('presented', 1.860759493670886),
#  ('resistance', 3.8524762908324552),
#  ('concerned', 3.1842105263157894),
#  ('previously', 2.992639327024185),
#  ('planning', 0.805672268907563),
#  ('managers', 3.25498426023085),
#  ('measured', 4.222222222222222),
#  ('brain', 2.498429319371728),
#  ('scientific', 2.0177824267782425),
#  ('perspective', 3.649947753396029),
#  ('functions', 1.6607515657620042),
#  ('sites', 0.37851929092805003),
#  ('standards', 1.0208333333333333),
#  ('travel', 0.22892819979188345),
#  ('half', 0.9646569646569647),
#  ('correct', 1.9179646936656283),
#  ('hotel', 0.21887966804979253),
#  ('south', 0.29637305699481864),
#  ('25', 0.0010351966873706005),
#  ('england', 1.2109617373319546),
#  ('14', 0.0010330578512396695),
#  ('changing', 2.5634674922600618),
#  ('balance', 2.0237113402061855),
#  ('property', 0.39855818743563337),
#  ('return', 0.36728395061728397),
#  ('name', 0.11099691675231244),
#  ('offer', 0.63347022587269),
#  ('occurs', 4.412307692307692),
#  ('respect', 1.742827868852459),
#  ('freedom', 2.1248720573183215),
#  ('woman', 1.1605316973415134),
#  ('fully', 1.7272727272727273),
#  ('press', 0.4306122448979592),
#  ('measures', 2.0682976554536188),
#  ('unit', 0.8706720977596741),
#  ('want', 0.25839267548321465),
#  ('felt', 2.434959349593496),
#  ('framework', 2.4944162436548223),
#  ('parts', 0.808316430020284),
#  ('popular', 0.6838905775075987),
#  ('objective', 3.422064777327935),
#  ('million', 0.6713852376137512),
#  ('media', 0.33434343434343433),
#  ('alternative', 1.498486377396569),
#  ('examination', 3.494959677419355),
#  ('truth', 2.2920443101711983),
#  ('oxford', 3.4969818913480886),
#  ('start', 0.4763819095477387),
#  ('reduction', 2.7610441767068274),
#  ('beginning', 1.679037111334002),
#  ('written', 0.8166332665330661),
#  ('step', 0.9309309309309309),
#  ('shall', 0.386),
#  ...]

# %%
sorted(res, key=lambda s:s[1], reverse=True)[:10]
# Out:
# [('cannot', 386.213768115942),
#  ('renold', 74.54856952761145),
#  ('ranke', 67.20519480519481),
#  ('ibid', 48.455555555555556),
#  ('radstone', 47.551252026661864),
#  ('trudgill', 44.13402876560771),
#  ('cenp', 43.753666361136574),
#  ('svevo', 42.932272029046224),
#  ('simmel', 39.19394561313494),
#  ('pentheus', 37.941635687732344)]

# %% [markdown]
# ## sort the result
# <span style="color: red">[ TODO ]</span> Please show top 30 uigrams in Rank Ratio and the value of their Rank Ratio in this format:
# <br>
# <img src="https://imgur.com/AEkiCRr.jpg" >

# %%
#### [ TODO ] souw the result

# %% [markdown]
# ## for Bigrams
# <span style="color: red">[ TODO ]</span> Do the Same Thing for Bigrams

# %%
#### [TODO]

# %% [markdown]
# ## TA's Notes
#
# If you complete the Assignment, please use [this link](https://docs.google.com/spreadsheets/d/1QGeYl5dsD9sFO9SYg4DIKk-xr-yGjRDOOLKZqCLDv2E/edit#gid=40492256) to reserve demo time.
# The score is only given after TAs review your implementation, so <u>**make sure you make a appointment with a TA before you miss the deadline**</u> .  <br>After demo, please upload your assignment to eeclass. You just need to hand in this ipynb file and rename it as XXXXXXXXX(Your student ID).ipynb.
# <br>Note that **late submission will not be allowed**.
